# %%
import cx_Oracle

# 211.170.143.158

dsn = cx_Oracle.makedsn('211.170.143.158', 1521, 'xe')
db = cx_Oracle.connect('test1', 'test1', dsn)

cursor = db.cursor()
cursor.execute("""select * from system.emp""")

row = cursor.fetchall()
row
# Out:
# [('0001',
#   '안영희',
#   '여',
#   '경영',
#   None,
#   datetime.datetime(1991, 1, 1, 0, 0),
#   4800,
#   0,
#   '01'),
#  ('0201',
#   '안영숙',
#   '여',
#   '지원',
#   '0001',
#   datetime.datetime(1991, 2, 1, 0, 0),
#   3900,
#   2000,
#   '01'),
#  ('0202',
#   '손하늘',
#   '여',
#   '지원',
#   '0001',
#   datetime.datetime(1991, 12, 1, 0, 0),
#   3510,
#   980,
#   '01'),
#  ('0301',
#   '이승철',
#   '남',
#   '회계',
#   '0001',
#   datetime.datetime(1992, 2, 1, 0, 0),
#   3400,
#   0,
#   '02'),
#  ('0302',
#   '박선경',
#   '여',
#   '회계',
#   '0301',
#   datetime.datetime(1991, 3, 2, 0, 0),
#   3300,
#   0,
#   '02'),
#  ('1001',
#   '문시현',
#   '남',
#   '모델링',
#   '0201',
#   datetime.datetime(1991, 2, 1, 0, 0),
#   4500,
#   520,
#   '10'),
#  ('1002',
#   '김주란',
#   '여',
#   '모델링',
#   '0201',
#   datetime.datetime(1992, 3, 3, 0, 0),
#   4100,
#   330,
#   '20'),
#  ('1003',
#   '양선호',
#   '남',
#   '모델링',
#   '0201',
#   datetime.datetime(1995, 2, 21, 0, 0),
#   4300,
#   None,
#   '30'),
# ...
